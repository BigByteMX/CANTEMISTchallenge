# %%
import numpy as np
import pandas as pd
import os
import re

# %%
def funcion1(path = 'data/train-set-to-publish/cantemist-ner/'):
    
    """Esta función sirve para leer los archivos de anotaciones y documentos contenidos en path/cantemist-ner/. 
    La entrada de esta función es un directorio con documentos .ann y .txt.
    La salida son dos diccionarios, uno con anotaciones y otro con documentos de texto."""
    
    
    ANNOTdict = {}
    CORPUSdict = {}
    
    filelist = os.listdir(path)

    for x in filelist:
        
        try:

            if x[-3:] == 'ann':
                tempdf = pd.read_csv(path+x,sep="\t",encoding='UTF8',)
                templabel = x[:-4]

                firstrow = pd.Series(pd.read_csv(path+x,sep="\t",encoding='UTF8',).columns,
                                     index=['T','MORFOLOGIA','CLAVE'])

                d = {}

                for y in enumerate(firstrow):

                    d[y[1]] = firstrow.index[y[0]]

                tempdf.rename(d,axis=1,inplace=True)

                tempdf = tempdf.append(firstrow,ignore_index=True)

                tempdf['T'].replace(
                    {"T1":"T01","T2":"T02","T3":"T03","T4":"T04","T5":"T05",
                     "T6":"T06","T7":"T07","T8":"T08","T9":"T09",},
                    inplace=True,)

                tempdf = tempdf.sort_values(by='T').reset_index(drop=True)

                ANNOTdict[templabel] = tempdf

            elif x[-3:] == 'txt':
                tempdf = pd.Series(data = open(path+x,encoding='UTF8').read())
                templabel = x[:-4]
                CORPUSdict[templabel] = tempdf
        
        except Exception as e: 
            print(f'{e} {path + x}')
        
    return (ANNOTdict,CORPUSdict)

# %%
def funcion2(ANNOTdict,CORPUSdict):
    
    
    """Esta función sirve para indexar la posición de las palabras contenidas en los archivos .ann dentro de su respectivo .txt.
    La entrada de esta función son dos diccionarios, uno de anotaciones y otro de documentos.
    La salida son dos diccionarios, el primero contiene la posición de las palabras indexada, el segundo contiene las anotaciones junto con la posición."""
    
    
    pos = {}


    for x in ANNOTdict.keys():
        pos[x] = pd.DataFrame(columns=['startposition','endposition'])

        templiststart = []

        templistend = []

        for y in enumerate(ANNOTdict[x]['CLAVE']):

            start = CORPUSdict[x][0].find(ANNOTdict[x]['CLAVE'][y[0]])
            end = CORPUSdict[x][0].find(ANNOTdict[x]['CLAVE'][y[0]]) + len(y[1])

            templiststart.append(start)
            templistend.append(end)

        pos[x]['startposition'] = templiststart
        pos[x]['endposition'] = templistend

        ANNOTdict[x] = ANNOTdict[x].join(pos[x])
    
    return pos,ANNOTdict

# %%
def funcion3(path = 'data/train-set-to-publish/cantemist-norm/'):

    """Esta función sirve para leer los archivos de anotaciones y documentos contenidos en path/cantemist-norm/. 
    La entrada de esta función es un directorio con documentos .ann y .txt.
    La salida son dos diccionarios, uno con anotaciones y otro con documentos de texto."""
    
    
    ANNOTdict = {}
    CORPUSdict = {}

    filelist = os.listdir(path)

    for x in filelist:

        try:
            if x[-3:] == 'ann':
                tempdf = pd.read_csv(path+x,sep="\t",encoding='UTF8',)
                templabel = x[:-4]

                firstrow = pd.Series(pd.read_csv(path+x,sep="\t",encoding='UTF8',).columns,
                                     index=['T','MORFOLOGIA','CLAVE'])

                d = {}

                for y in enumerate(firstrow):

                    d[y[1]] = firstrow.index[y[0]]

                tempdf.rename(d,axis=1,inplace=True)

                tempdf = tempdf.append(firstrow,ignore_index=True)

                tempdf['T'].replace(
                    {"#":"U"},
                    inplace=True,regex=True)

                tempdf['T'].replace(
                    {"T1":"T01","T2":"T02","T3":"T03","T4":"T04","T5":"T05",
                     "T6":"T06","T7":"T07","T8":"T08","T9":"T09",},
                    inplace=True,)

                tempdf['T'].replace(
                    {"U1":"U01","U2":"U02","U3":"U03","U4":"U04","U5":"U05",
                     "U6":"U06","U7":"U07","U8":"U08","U9":"U09",},
                    inplace=True,)

                tempdf = tempdf.sort_values(by='T').reset_index(drop=True)

                ICDcode = tempdf[tempdf['T'].apply(lambda x: x[0]=='U')].rename(
                    {'CLAVE':'ICD-O-3'},axis=1).reset_index(drop=True)['ICD-O-3']

                tempdf = tempdf[tempdf['T'].apply(lambda x: x[0]=='T')].join(ICDcode,)


                ANNOTdict[templabel] = tempdf

                
        except Exception as e: 
                print(f'{e} {path + x}')
                
    return (ANNOTdict,CORPUSdict)

# %%
def funcion4(dict1=funcion2(funcion1()[0],funcion1()[1])[1],
             dict2=funcion3()[0]):
    
    
    """Esta función sirve para . 
    La primer entrada es un diccionario de archivos .ann que contiene la posición de palabras a indexar.
    La segunda entrada es un diccionario de archivos .ann que contiene el código ICD-O-3.
    La es un diccionario que contiene posición y código ICD-O-3."""
    
    
    tempdict = {}

    for x in dict1.keys():
                
        tempdict[x] = dict1[x].join(dict2[x]['ICD-O-3'])
    
    return tempdict
# Out:
# No columns to parse from file data/train-set-to-publish/cantemist-ner/cc_onco853.ann
# No columns to parse from file data/train-set-to-publish/cantemist-ner/cc_onco853.ann
# No columns to parse from file data/train-set-to-publish/cantemist-norm/cc_onco853.ann

# %%
def funcion5(dict1=funcion4()):
    
    """Regresa una tabla que contiene una morfología encontrada, posición de inicio y de fin, 
    ICD-O-3 y documento en donde se encontró"""
    
    final_df = pd.DataFrame()
    tempdf = pd.DataFrame()

    for key in dict1:
        tempdf = dict1[key]
        tempdf['document'] = key

        final_df = final_df.append(tempdf)
        
    return final_df

# %%
def funcion6(trainset = funcion5(), CORPUSdict = funcion1('data/test-background-set-to-publish/')[1],):
    
    """Busca las morfologias contenidas en el set de entrenamiento, dentro de los documentos contenidos en el set de prueba. 
    El set de entrenamiento tiene  filas.
    La salida es un diccionario con las morfologias encontradas, ICD-O-3, documento, índice dentro del documento."""


    tempdf = trainset[['CLAVE','ICD-O-3']][trainset['CLAVE'].apply(lambda x: x.lower()).duplicated() == False]

    tempdf['len'] = tempdf['CLAVE'].apply(lambda x: len(x))
    
    finaldf = pd.DataFrame()

    tempdict = {}
    
    for key in CORPUSdict.keys():

        tempdict[key] = pd.DataFrame()
        
        text = CORPUSdict[key][0]

        for word,code in zip(tempdf['CLAVE'],tempdf['ICD-O-3']):
            
            if len(word)>4:

                startindex = text.lower().find(word.lower())

                if startindex != -1:
                    
                    endindex = startindex+len(word)
                    
                    tempseries = pd.Series(data={'CLAVE':word,'startpos':startindex,'endpos':endindex,'ICD-O-3':code,'documento':key})

                    finaldf = finaldf.append(tempseries,ignore_index=True,)
                
            elif len(word)<=4:
                
                startindex = text.find(word)
                        
                if startindex != -1:
                    
                    endindex = startindex+len(word)
                    
                    if(text[startindex-1] == ' ') or (text[startindex-1] == '\n') or (text[startindex-1] == '.') or (text[startindex-1] == '-') or (text[startindex-1] == ':') or (text[startindex-1] == ';') or (text[startindex-1] == '(') or (text[startindex-1] == ')') or (text[startindex-1] == ',') : 
                    
                        try:
                    
                            if (text[endindex+1] == ' ') or (text[endindex+1] == '\n') or (text[endindex+1] == '.') or (text[endindex+1] == '-') or (text[endindex+1] == ':') or (text[endindex+1] == ';') or (text[startindex-1] == '(') or (text[startindex-1] == ')') or (text[startindex-1] == ',') :

                                tempseries = pd.Series(data={'CLAVE':word,'startpos':startindex,'endpos':endindex,'ICD-O-3':code,'documento':key})

                                finaldf = finaldf.append(tempseries,ignore_index=True,)
                                
                        except:
                            
                            if (len(text) == endindex):
                                
                                tempseries = pd.Series(data={'CLAVE':word,'startpos':startindex,'endpos':endindex,'ICD-O-3':code,'documento':key})

                                finaldf = finaldf.append(tempseries,ignore_index=True,)


    d1 = {}
    for k in finaldf['documento'].unique():
        d1[k] = finaldf[finaldf['documento']==k]
        
    for key in d1.keys():
        
        d1[key]['len'] = d1[key]['CLAVE'].apply(lambda x: len(x))
        
        d1[key] = d1[key].sort_values(by = ['len'],ascending=False)[d1[key].sort_values(by = ['len'],ascending=False)['startpos'].duplicated() == False].sort_values('startpos').reset_index(drop=True)
        
        d1[key] = d1[key].sort_values(by = ['len'],ascending=False)[d1[key].sort_values(by = ['len'],ascending=False)['endpos'].duplicated() == False].sort_values('startpos').reset_index(drop=True)
        
        d1[key].index = map(lambda x: "T"+str(x+1), d1[key].index)
        
        d1[key].drop('len',axis=1,inplace=True)
 
        
    return (d1,tempdf)

# %%
d2 = funcion6()
# Out:
# C:\Users\L03040999\Anaconda3\lib\site-packages\ipykernel_launcher.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
len(d2[0].keys())
# Out:
# 2809

# %%
d2[1]
# Out:
#                                           CLAVE ICD-O-3  len
# 0                         Carcinoma microcítico  8041/3   21
# 2                                            M0  8000/6    2
# 0                                   metastásica  8000/6   11
# 1                                    metástasis  8000/6   10
# 3                                     neoplasia  8000/1    9
# ..                                          ...     ...  ...
# 21                        implante rectovesical  8000/6   21
# 22          implantes en cara anterior de recto  8000/6   35
# 23                        implante en mesocolon  8000/6   21
# 2   carcinoma urotelial de vejiga de alto grado  8120/3   43
# 0                                 Paraganglioma  8680/1   13
#
# [3397 rows x 3 columns]

# %%
# def funcion7(d1=funcion6()[0])):
def funcion7(d1,traindf): 
    
    """Regresa las morfologias encontradas en formato NERbrat y NORMbrat."""
    
    NERbratformat = {}

    for key in d1.keys():

        d1[key]['MORFOLOGIA NEOPLASIA'] = 'MORFOLOGIA_NEOPLASIA'

        NERbratformat[key] = d1[key][['MORFOLOGIA NEOPLASIA','startpos','endpos','CLAVE']]
        
        NERbratformat[key][['startpos','endpos']] = NERbratformat[key][['startpos','endpos']].astype(int)
        
        NERbratformat[key].to_csv(f'data/team_bigbyte/cantemist-ner/{key}.ann', header=False, index=True, sep='\t',)
        
    NORMbratformat = {}

    
    for key in NERbratformat.keys():

        NORMbratformat[key] = pd.DataFrame()
        
        NERbratformat[key][['startpos','endpos']] = NERbratformat[key][['startpos','endpos']].astype(int)

        for i,row in enumerate(NERbratformat[key].index):
            tempseries = NERbratformat[key].loc[row].append(pd.Series(data={'index':row},name=row))

            tempseries2 = pd.Series(data = {
                'index':'#'+str(i+1), 'MORFOLOGIA NEOPLASIA':f'AnnotatorNotes {row}','startpos':d1[key].iloc[i]['ICD-O-3']}, 
                                    name=row
                                   )
            
            tempdf = pd.concat([tempseries,tempseries2],axis=1).T.set_index('index').reset_index()

            NORMbratformat[key] = NORMbratformat[key].append(tempdf)
            
        NORMbratformat[key].to_csv(f'data/team_bigbyte/cantemist-norm/{key}.ann', header=False, index=False, sep='\t', )
        
    
    tempdf = pd.DataFrame()

    for x in d1.keys():
    
        tempdf = tempdf.append(d1[x].sort_values(by='startpos')[['documento','ICD-O-3']])
        
    
    tempdf.to_csv(f'data/team_bigbyte/cantemist-coding/coding.tsv', header=False, index=False, sep='\t', )
    traindf.sort_values(by='CLAVE').to_csv(f'data/team_bigbyte/traindf.txt', header=True, index=False, sep='\t', )

# %%
funcion7(d2[0],d2[1])
# Out:
# C:\Users\L03040999\Anaconda3\lib\site-packages\pandas\core\frame.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
d2[1].sort_values(by='CLAVE')
# Out:
#                       CLAVE ICD-O-3  len
# 10           (LOE ) frontal  8000/6   14
# 18  (LOE) de 15 mm hepática  8000/6   23
# 11       (LOE) en el hígado  8000/6   18
# 9            (LOE) hepática  8000/6   14
# 13          (LOE) hepáticas  8000/6   15
# ..                      ...     ...  ...
# 11                ypT3N0/M0  8000/6    9
# 12                 ypT3N0M0  8000/6    8
# 14                 ypT3N1M0  8000/6    8
# 13                ypT3cN1M0  8000/6    9
# 13                 ypT4N0M0  8000/6    8
#
# [3397 rows x 3 columns]

# %%
d2[0]
# Out:
# {'caso_clinico_radiologia1':         CLAVE ICD-O-3                 documento  endpos  startpos
#  T1  formación  8000/1  caso_clinico_radiologia1   564.0     555.0,
#  'caso_clinico_radiologia10':                        CLAVE ICD-O-3                  documento  endpos  \
#  T1       masas suprarrenales  8000/6  caso_clinico_radiologia10  1167.0
#  T2                 neoplasia  8000/1  caso_clinico_radiologia10  1253.0
#  T3                 Carcinoma  8010/3  caso_clinico_radiologia10  1283.0
#  T4                 poliposis  8210/0  caso_clinico_radiologia10  1331.0
#  T5  Carcinoma indiferenciado  8020/3  caso_clinico_radiologia10  1420.0
#  T6                metástasis  8000/6  caso_clinico_radiologia10  1459.0
#
#      startpos
#  T1    1148.0
#  T2    1244.0
#  T3    1274.0
#  T4    1322.0
#  T5    1396.0
#  T6    1449.0  ,
#  'caso_clinico_radiologia1000':       CLAVE ICD-O-3                    documento  endpos  startpos
#  T1  linfoma  9590/3  caso_clinico_radiologia1000   285.0     278.0,
#  'caso_clinico_radiologia1002':                 CLAVE ICD-O-3                    documento  endpos  startpos
#  T1  neoplasia maligna  8000/3  caso_clinico_radiologia1002   367.0     350.0,
#  'caso_clinico_radiologia1004':     CLAVE ICD-O-3                    documento  endpos  startpos
#  T1  tumor  8000/1  caso_clinico_radiologia1004   396.0     391.0,
#  'caso_clinico_radiologia1006':                   CLAVE ICD-O-3                    documento  endpos  startpos
#  T1  enfermedad pulmonar  8000/6  caso_clinico_radiologia1006   464.0     445.0,
#  'caso_clinico_radiologia1007':         CLAVE ICD-O-3                    documento  endpos  startpos
#  T1  formación  8000/1  caso_clinico_radiologia1007   254.0     245.0,
#  'caso_clinico_radiologia1008':          CLAVE ICD-O-3                    documento  endpos  startpos
#  T1  tumoración  8000/1  caso_clinico_radiologia1008   599.0     589.0,
#  'caso_clinico_radiologia101':        CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  implante  8000/6  caso_clinico_radiologia101    51.0      43.0,
#  'caso_clinico_radiologia1011':    CLAVE ICD-O-3                    documento  endpos  startpos
#  T1    SE  9260/3  caso_clinico_radiologia1011  2470.0    2468.0,
#  'caso_clinico_radiologia11':              CLAVE ICD-O-3                  documento  endpos  startpos
#  T1  adenocarcinoma  8140/3  caso_clinico_radiologia11    82.0      68.0,
#  'caso_clinico_radiologia111':          CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  malignidad  8000/3  caso_clinico_radiologia111   527.0     517.0,
#  'caso_clinico_radiologia115':            CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  neurofibroma  9540/0  caso_clinico_radiologia115    57.0      45.0,
#  'caso_clinico_radiologia116':         CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  Carcinoma  8010/3  caso_clinico_radiologia116    46.0      37.0,
#  'caso_clinico_radiologia119':          CLAVE ICD-O-3                   documento  endpos  startpos
#  T1   neoplasia  8000/1  caso_clinico_radiologia119   424.0     415.0
#  T2  metástasis  8000/6  caso_clinico_radiologia119   756.0     746.0
#  T3    oat cell  8002/3  caso_clinico_radiologia119   810.0     802.0,
#  'caso_clinico_radiologia12':                            CLAVE ICD-O-3                  documento  endpos  \
#  T1  afectación de partes blandas  8000/6  caso_clinico_radiologia12   681.0
#
#      startpos
#  T1     653.0  ,
#  'caso_clinico_radiologia120':                       CLAVE ICD-O-3                   documento  endpos  \
#  T1  pseudomixoma peritoneal  8480/6  caso_clinico_radiologia120   665.0
#  T2                   mixoma  8840/0  caso_clinico_radiologia120   654.0
#
#      startpos
#  T1     642.0
#  T2     648.0  ,
#  'caso_clinico_radiologia122':         CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  formación  8000/1  caso_clinico_radiologia122   702.0     693.0,
#  'caso_clinico_radiologia126':                     CLAVE ICD-O-3                   documento  endpos  \
#  T1  cistoadenoma mucinoso  8470/0  caso_clinico_radiologia126   535.0
#  T2                adenoma  8140/0  caso_clinico_radiologia126   526.0
#  T3             malignidad  8000/3  caso_clinico_radiologia126   572.0
#
#      startpos
#  T1     514.0
#  T2     519.0
#  T3     562.0  ,
#  'caso_clinico_radiologia128':          CLAVE ICD-O-3                   documento  endpos  startpos
#  T1     tumoral  8000/1  caso_clinico_radiologia128   667.0     660.0
#  T2  malignidad  8000/3  caso_clinico_radiologia128  1278.0    1268.0,
#  'caso_clinico_radiologia13':         CLAVE ICD-O-3                  documento  endpos  startpos
#  T1  Carcinoma  8010/3  caso_clinico_radiologia13    46.0      37.0
#  T2      tumor  8000/1  caso_clinico_radiologia13  1116.0    1111.0,
#  'caso_clinico_radiologia130':              CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  angiomiolipoma  8860/0  caso_clinico_radiologia130   425.0     411.0,
#  'caso_clinico_radiologia132':              CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  Carcinomatosis  8010/9  caso_clinico_radiologia132  1000.0     986.0
#  T2  adenocarcinoma  8140/3  caso_clinico_radiologia132  1219.0    1205.0
#  T3           tumor  8000/1  caso_clinico_radiologia132  1252.0    1247.0
#  T4      metástasis  8000/6  caso_clinico_radiologia132  1286.0    1276.0,
#  'caso_clinico_radiologia134':          CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  tumoración  8000/1  caso_clinico_radiolog
                      CLAVE ICD-O-3                   documento  endpos  \
#  T1  adenocarcinoma papilar  8260/3  caso_clinico_radiologia260   471.0
#
#      startpos
#  T1     449.0  ,
#  'caso_clinico_radiologia263':                                            CLAVE ICD-O-3  \
#  T1                                     tumorales  8000/1
#  T2  neoplasia mucinosa apendicular de bajo grado  8480/1
#
#                       documento  endpos  startpos
#  T1  caso_clinico_radiologia263   118.0     109.0
#  T2  caso_clinico_radiologia263   744.0     700.0  ,
#  'caso_clinico_radiologia266':                        CLAVE ICD-O-3                   documento  endpos  \
#  T1  síndrome mielodisplásico  9989/3  caso_clinico_radiologia266   300.0
#
#      startpos
#  T1     276.0  ,
#  'caso_clinico_radiologia267':         CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  Carcinoma  8010/3  caso_clinico_radiologia267   116.0     107.0,
#  'caso_clinico_radiologia268':                    CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  tumor neuroendocrino  8240/3  caso_clinico_radiologia268    57.0      37.0
#  T2       lóbulo hepático  8000/6  caso_clinico_radiologia268   604.0     589.0,
#  'caso_clinico_radiologia272':                  CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  lesiones hepáticas  8000/6  caso_clinico_radiologia272   653.0     635.0
#  T2            malignas  8000/3  caso_clinico_radiologia272  1114.0    1106.0,
#  'caso_clinico_radiologia278':          CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  neoplásico  8000/1  caso_clinico_radiologia278   337.0     327.0,
#  'caso_clinico_radiologia281':               CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  angiomiolipomas  8860/0  caso_clinico_radiologia281   324.0     309.0,
#  'caso_clinico_radiologia282':            CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  masa anexial  8000/6  caso_clinico_radiologia282   519.0     507.0,
#  'caso_clinico_radiologia283':         CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  formación  8000/1  caso_clinico_radiologia283   388.0     379.0,
#  'caso_clinico_radiologia284':         CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  neoplasia  8000/1  caso_clinico_radiologia284    96.0      87.0
#  T2    adenoma  8140/0  caso_clinico_radiologia284   150.0     143.0,
#  'caso_clinico_radiologia285':           CLAVE ICD-O-3                   documento  endpos  startpos
#  T1       cáncer  8000/3  caso_clinico_radiologia285    88.0      82.0
#  T2  metastásico  8000/6  caso_clinico_radiologia285   109.0      98.0,
#  'caso_clinico_radiologia287':      CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  cáncer  8000/3  caso_clinico_radiologia287    68.0      62.0,
#  'caso_clinico_radiologia291':                        CLAVE ICD-O-3                   documento  endpos  \
#  T1  síndrome mielodisplásico  9989/3  caso_clinico_radiologia291    84.0
#
#      startpos
#  T1      60.0  ,
#  'caso_clinico_radiologia293':       CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  sarcoma  8800/3  caso_clinico_radiologia293   108.0     101.0,
#  'caso_clinico_radiologia296':        CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  leucemia  9800/3  caso_clinico_radiologia296   216.0     208.0
#  T2       LMA  9861/3  caso_clinico_radiologia296   236.0     233.0,
#  'caso_clinico_radiologia299':                       CLAVE ICD-O-3                   documento  endpos  \
#  T1                 seminoma  9061/3  caso_clinico_radiologia299    46.0
#  T2  metástasis del seminoma  9061/6  caso_clinico_radiologia299   493.0
#
#      startpos
#  T1      38.0
#  T2     470.0  ,
#  'caso_clinico_radiologia3':        CLAVE ICD-O-3                 documento  endpos  startpos
#  T1  implante  8000/6  caso_clinico_radiologia3   575.0     567.0,
#  'caso_clinico_radiologia31':          CLAVE ICD-O-3                  documento  endpos  startpos
#  T1  tumoración  8000/1  caso_clinico_radiologia31   340.0     330.0,
#  'caso_clinico_radiologia311':       CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  maligna  8000/3  caso_clinico_radiologia311   646.0     639.0,
#  'caso_clinico_radiologia317':         CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  formación  8000/1  caso_clinico_radiologia317   936.0     927.0,
#  'caso_clinico_radiologia318':                    CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  masa retroperitoneal  8000/6  caso_clinico_radiologia318  1289.0    1269.0
#  T2            tumoración  8000/1  caso_clinico_radiologia318  1374.0    1364.0
#  T3            metástasis  8000/6  caso_clinico_radiologia318  1561.0    1551.0,
#  'caso_clinico_radiologia319':               CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  lóbulo hepático  8000/6  caso_clinico_radiologia319   347.0     332.0,
#  'caso_clinico_radiologia322':            CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  neoformativo  8000/1  caso_clinico_radiologia322   521.0     509.0
#  T2  neoformación  8000/1  caso_clinico_radiologia322   846.0     834.0,
#  'caso_clinico_radiologia330':                                   CLAVE ICD-O-3                   documento  \
#  T1  linfoma B difuso de células grandes  9680/3  caso_clinico_radiologia330
#
#      endpos  startpos
#  T1   753.0     718.0  ,
#  'caso_clinico_radiologia331':                      CLAVE ICD-O-3                   documento  endpos  \
#  T1               neoplasia  8000/1  caso_clinico_radiologia331    47.0
#  T2  implantes peritoneales  8000/6  caso_clinico_radiologia331   127.0
#
#      startpos
#  T1      38.0
#  T2     105.0  ,
#  'caso_clinico_radiologia334':                      CLAVE ICD-O-3                   documento  endpos  \
#  T1  masa de partes blandas  8000/6  caso_clinico_radiologia334   363.0
#
#      startpos
#  T1     341.0  ,
#  'caso_clinico_radiologia338':                      CLAVE ICD-O-3                   documento  endpos  \
#  T1  masa de partes blandas  8000/6  caso_clinico_radiologia338   293.0
#  T2                 linfoma  9590/3  caso_clinico_radiologia338   868.0
#  T3                   LDCGB  9680/3  caso_clinico_radiologia338   902.0
#
#      startpos
#  T1     271.0
#  T2     861.0
#  T3     897.0  ,
#  'caso_clinico_radiologia340':         CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  formación  8000/1  caso_clinico_radiologia340   618.0     609.0,
#  'caso_clinico_radiologia345':                  CLAVE ICD-O-3                   documento  endpos  startpos
#  T1    lesión esplénica  8000/6  caso_clinico_radiologia345   295.0     279.0
#  T2  lesiones hepáticas  8000/6  caso_clinico_radiologia345   514.0     496.0
#  T3               tumor  8000/1  caso_clinico_radiologia345   723.0     718.0
#  T4             maligno  8000/3  caso_clinico_radiologia345   740.0     733.0,
#  'caso_clinico_radiologia347':            CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  masa pélvica  8000/6  caso_clinico_radiologia347   178.0     166.0,
#  'caso_clinico_radiologia348':                              CLAVE ICD-O-3                   documento  \
#  T1    Melanoma cutáneo metastásico  8720/6  caso_clinico_radiologia348
#  T2                      metástasis  8000/6  caso_clinico_radiologia348
#  T3  nódulos pulmonares bilaterales  8000/6  caso_clinico_radiologia348
#  T4                   lesión lítica  8000/6  caso_clinico_radiologia348
#
#      endpos  startpos
#  T1    64.0      36.0
#  T2   169.0     159.0
#  T3   804.0     774.0
#  T4   862.0     849.0  ,
#  'caso_clinico_radiologia349':         CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  formación  8000/1  caso_clinico_radiologia349  1201.0    1192.0,
#  'caso_clinico_radiologia36':              CLAVE ICD-O-3                  documento  endpos  startpos
#  T1  adenocarcinoma  8140/3  caso_clinico_radiologia36    48.0      34.0,
#  'caso_clinico_radiologia360':               CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  teratoma maduro  9080/0  caso_clinico_radiologia360   499.0     484.0,
#  'caso_clinico_radiologia365':         CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  neoplasia  8000/1  caso_clinico_radiologia365   145.0     136.0
#  T2         Ca  8000/3  caso_clinico_radiologia365   215.0     213.0,
#  'caso_clinico_radiologia366':               CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  afectación ósea  8000/6  caso_clinico_radiologia366   690.0     675.0,
#  'caso_clinico_radiologia367':      CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  cáncer  8000/3  caso_clinico_radiologia367   492.0     486.0,
#  'caso_clinico_radiologia368':                      CLAVE ICD-O-3                   documento  endpos  \
#  T1  masa de partes blandas  8000/6  caso_clinico_radiologia368   335.0
#
#      startpos
#  T1     313.0  ,
#  'caso_clinico_radiologia372':                        CLAVE ICD-O-3                   documento  endpos  \
#  T1            adenocarcinoma  8140/3  caso_clinico_radiologia372    84.0
#  T2                metástasis  8000/6  caso_clinico_radiologia372   111.0
#  T3       afectación meníngea  8000/6  caso_clinico_radiologia372   615.0
#  T4  metástasis del carcinoma  8010/6  caso_clinico_radiologia372  1197.0
#
#      startpos
#  T1      70.0
#  T2     101.0
#  T3     596.0
#  T4    1173.0  ,
#  'caso_clinico_radiologia373':              CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  angiomiolipoma  8860/0  caso_clinico_radiologia373    69.0      55.0
#  T2     peritumoral  8000/1  caso_clinico_radiologia373   403.0     392.0,
#  'caso_clinico_radiologia375':          CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  tumoración  8000/1  caso_clinico_radiologia375   480.0     470.0,
#  'caso_clinico_radiologia38':          CLAVE ICD-O-3                  documento  endpos  startpos
#  T1   formación  8000/1  caso_clinico_radiologia38   889.0     880.0
#  T2     tumoral  8000/1  caso_clinico_radiologia38   937.0     930.0
#  T3  neoplásico  8000/1  caso_clinico_radiologia38  1512.0    1502.0
#  T4  meningioma  9530/0  caso_clinico_radiologia38  1566.0    1556.0,
#  'caso_clinico_radiologia381':       CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  tumoral  8000/1  caso_clinico_radiologia381   412.0     405.0,
#  'caso_clinico_radiologia386':            CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  masa pélvica  8000/6  caso_clinico_radiologia386   308.0     296.0,
#  'caso_clinico_radiologia39':         CLAVE ICD-O-3                  documento  endpos  startpos
#  T1  neoplasia  8000/1  caso_clinico_radiologia39   476.0     467.0,
#  'caso_clinico_radiologia391':      CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  cáncer  8000/3  caso_clinico_radiologia391    43.0      37.0,
#  'caso_clinico_radiologia394':          CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  metástasis  8000/6  caso_clinico_radiologia394   625.0     615.0,
#  'caso_clinico_radiologia396':                     CLAVE ICD-O-3                   documento  endpos  \
#  T1  lesión focal hepática  8000/6  caso_clinico_radiologia396   334.0
#  T2                tumoral  8000/1  caso_clinico_radiologia396   855.0
#  T3        hepatocarcinoma  8170/3  caso_clinico_radiologia396  1028.0
#
#      startpos
#  T1     313.0
#  T2     848.0
#  T3    1013.0  ,
#  'caso_clinico_radiologia398':         CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  neurinoma  9560/0  caso_clinico_radiologia398   585.0     576.0,
#  'caso_clinico_radiologia4':    CLAVE ICD-O-3                 documento  endpos  startpos
#  T1    MO  8000/6  caso_clinico_radiologia4   401.0     399.0,
#  'caso_clinico_radiologia401':                         CLAVE ICD-O-3                   documento  endpos  \
#  T1                  Carcinoma  8010/3  caso_clinico_radiologia401   295.0
#  T2  linfangitis carcinomatosa  8000/3  caso_clinico_radiologia401   709.0
#
#      startpos
#  T1     286.0
#  T2     684.0  ,
#  'caso_clinico_radiologia402':                         CLAVE ICD-O-3                   documento  endpos  \
#  T1                mesotelioma  9050/3  caso_clinico_radiologia402    87.0
#  T2  linfangitis carcinomatosa  8000/3  caso_clinico_radiologia402   687.0
#
#      startpos
#  T1      76.0
#  T2     662.0  ,
#  'caso_clinico_radiologia406':                                            CLAVE ICD-O-3  \
#  T1  neoplasia mucinosa apendicular de bajo grado  8480/1
#
#                       documento  endpos  startpos
#  T1  caso_clinico_radiologia406   531.0     487.0  ,
#  'caso_clinico_radiologia407':                          CLAVE ICD-O-3                   documento  endpos  \
#  T1                     linfoma  9590/3  caso_clinico_radiologia407   759.0
#  T2  proceso linfoproliferativo  9970/1  caso_clinico_radiologia407   849.0
#
#      startpos
#  T1     752.0
#  T2     823.0  ,
#  'caso_clinico_radiologia410':         CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  formación  8000/1  caso_clinico_radiologia410   577.0     568.0,
#  'caso_clinico_radiologia414':                          CLAVE ICD-O-3                   documento  endpos  \
#  T1  consolidaciones pulmonares  8000/6  caso_clinico_radiologia414  1141.0
#
#      startpos
#  T1    1115.0  ,
#  'caso_clinico_radiologia415':         CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  cavernoma  9121/0  caso_clinico_radiologia415   381.0     372.0
#  T2  formación  8000/1  caso_clinico_radiologia415   437.0     428.0
#  T3    Angioma  9120/0  caso_clinico_radiologia415   584.0     577.0,
#  'caso_clinico_radiologia416':             CLAVE ICD-O-3                   documento  endpos  startpos
#  T1     tumoración  8000/1  caso_clinico_radiologia416   373.0     363.0
#  T2  neuroblastoma  9500/3  caso_clinico_radiologia416   893.0     880.0,
#  'caso_clinico_radiologia423':          CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  tumoración  8000/1  caso_clinico_radiologia423   210.0     200.0,
#  'caso_clinico_radiologia424':       CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  maligna  8000/3  caso_clinico_radiologia424   549.0     542.0,
#  'caso_clinico_radiologia425':                              CLAVE ICD-O-3                   documento  \
#  T1  poliposis adenomatosa familiar  8220/0  caso_clinico_radiologia425
#  T2                     adenomatosa  8140/0  caso_clinico_radiologia425
#
#      endpos  startpos
#  T1    90.0      60.0
#  T2    81.0      70.0  ,
#  'caso_clinico_radiologia430':            CLAVE ICD-O-3                   documento  endpos  startpos
#  T1    tumoración  8000/1  caso_clinico_radiologia430   249.0     239.0
#  T2  masa anexial  8000/6  caso_clinico_radiologia430   359.0     347.0,
#  'caso_clinico_radiologia435':            CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  tumoraciones  8000/1  caso_clinico_radiologia435   323.0     311.0
#  T2       tumoral  8000/1  caso_clinico_radiologia435   728.0     721.0,
#  'caso_clinico_radiologia440':                     CLAVE ICD-O-3                   documento  endpos  \
#  T1      Masa mediastínica  8000/6  caso_clinico_radiologia440   448.0
#  T2  afectación peritoneal  8000/6  caso_clinico_radiologia440   779.0
#  T3           omental cake  8000/6  caso_clinico_radiologia440   805.0
#  T4         Carcinomatosis  8010/9  caso_clinico_radiologia440   906.0
#  T5                  tumor  8000/1  caso_clinico_radiologia440   936.0
#  T6                linfoma  9590/3  caso_clinico_radiologia440   957.0
#
#      startpos
#  T1     431.0
#  T2     758.0
#  T3     793.0
#  T4     892.0
#  T5     931.0
#  T6     950.0  ,
#  'caso_clinico_radiologia441':            CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  cistoadenoma  8440/0  caso_clinico_radiologia441   650.0     638.0,
#  'caso_clinico_radiologia443':                CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  masa suprarrenal  8000/6  caso_clinico_radiologia443   560.0     544.0
#  T2    feocromocitoma  8700/3  caso_clinico_radiologia443   693.0     679.0,
#  'caso_clinico_radiologia445':          CLAVE ICD-O-3                   documento  endpos  startpos
#  T1    teratoma  9080/1  caso_clinico_radiologia445   410.0     402.0
#  T2  tumoración  8000/1  caso_clinico_radiologia445   638.0     628.0
#  T3  malignidad  8000/3  caso_clinico_radiologia445  1159.0    1149.0,
#  'caso_clinico_radiologia448':          CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  metástasis  8000/6  caso_clinico_radiologia448   802.0     792.0,
#  'caso_clinico_radiologia45':               CLAVE ICD-O-3                  documento  endpos  startpos
#  T1  lóbulo hepático  8000/6  caso_clinico_radiologia45   795.0     780.0,
#  'caso_clinico_radiologia464':       CLAVE ICD-O-3                   documento  endpos  startpos
#  T1    Mioma  8895/0  caso_clinico_radiologia464   426.0     421.0
#  T2  tumoral  8000/1  caso_clinico_radiologia464   525.0     518.0,
#  'caso_clinico_radiologia465':                CLAVE ICD-O-3                   documento  endpos  startpos
#  T1
       CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  Angioma  9120/0  caso_clinico_radiologia567   872.0     865.0,
#  'caso_clinico_radiologia569':                       CLAVE ICD-O-3                   documento  endpos  \
#  T1           Carcinomatosis  8010/9  caso_clinico_radiologia569   789.0
#  T2   implantes mesentéricos  8000/6  caso_clinico_radiologia569   913.0
#  T3  pseudomixoma peritoneal  8480/6  caso_clinico_radiologia569  1038.0
#  T4                   mixoma  8840/0  caso_clinico_radiologia569  1027.0
#
#      startpos
#  T1     775.0
#  T2     891.0
#  T3    1015.0
#  T4    1021.0  ,
#  'caso_clinico_radiologia575':          CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  metástasis  8000/6  caso_clinico_radiologia575   552.0     542.0
#  T2   neoplasia  8000/1  caso_clinico_radiologia575   580.0     571.0
#  T3     tumoral  8000/1  caso_clinico_radiologia575   676.0     669.0,
#  'caso_clinico_radiologia579':                   CLAVE ICD-O-3                   documento  endpos  startpos
#  T1       leucemia aguda  9801/3  caso_clinico_radiologia579   290.0     276.0
#  T2                  LAM  9861/3  caso_clinico_radiologia579   310.0     307.0
#  T3  afectación cerebral  8000/6  caso_clinico_radiologia579   842.0     823.0,
#  'caso_clinico_radiologia580':                                  CLAVE ICD-O-3                   documento  \
#  T1  tumor del estroma gastrointestinal  8936/3  caso_clinico_radiologia580
#
#      endpos  startpos
#  T1    84.0      50.0  ,
#  'caso_clinico_radiologia584':                CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  lesión esplénica  8000/6  caso_clinico_radiologia584   924.0     908.0
#  T2           linfoma  9590/3  caso_clinico_radiologia584   948.0     941.0,
#  'caso_clinico_radiologia585':                CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  células malignas  8001/3  caso_clinico_radiologia585   870.0     854.0,
#  'caso_clinico_radiologia587':                    CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  nódulos peritoneales  8000/6  caso_clinico_radiologia587   409.0     389.0,
#  'caso_clinico_radiologia595':                     CLAVE ICD-O-3                   documento  endpos  \
#  T1  Enfermedad de Hodgkin  9650/3  caso_clinico_radiologia595    42.0
#
#      startpos
#  T1      21.0  ,
#  'caso_clinico_radiologia596':           CLAVE ICD-O-3                   documento  endpos  startpos
#  T1       cáncer  8000/3  caso_clinico_radiologia596    44.0      38.0
#  T2  metastásica  8000/6  caso_clinico_radiologia596   405.0     394.0,
#  'caso_clinico_radiologia598':               CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  lesión hepática  8000/6  caso_clinico_radiologia598   217.0     202.0,
#  'caso_clinico_radiologia6':              CLAVE ICD-O-3                 documento  endpos  startpos
#  T1  Carcinomatosis  8010/9  caso_clinico_radiologia6   729.0     715.0
#  T2         linfoma  9590/3  caso_clinico_radiologia6   749.0     742.0
#  T3      neoplasias  8000/1  caso_clinico_radiologia6   768.0     758.0,
#  'caso_clinico_radiologia603':     CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  Mioma  8895/0  caso_clinico_radiologia603    59.0      54.0,
#  'caso_clinico_radiologia604':          CLAVE ICD-O-3                   documento  endpos  startpos
#  T1       Mioma  8895/0  caso_clinico_radiologia604   106.0     101.0
#  T2  tumoración  8000/1  caso_clinico_radiologia604   180.0     170.0,
#  'caso_clinico_radiologia605':          CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  tumoración  8000/1  caso_clinico_radiologia605    95.0      85.0,
#  'caso_clinico_radiologia607':         CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  neoplasia  8000/1  caso_clinico_radiologia607   485.0     476.0,
#  'caso_clinico_radiologia608':          CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  tumoración  8000/1  caso_clinico_radiologia608   141.0     131.0,
#  'caso_clinico_radiologia61':                                    CLAVE ICD-O-3                  documento  \
#  T1                               linfoma  9590/3  caso_clinico_radiologia61
#  T2                        adenocarcinoma  8140/3  caso_clinico_radiologia61
#  T3                        Carcinomatosis  8010/9  caso_clinico_radiologia61
#  T4  tumores del estroma gastrointestinal  8936/3  caso_clinico_radiologia61
#  T5                                  GIST  8936/3  caso_clinico_radiologia61
#  T6                      tumor carcinoide  8240/3  caso_clinico_radiologia61
#  T7                  Melanoma metastásico  8720/6  caso_clinico_radiologia61
#  T8                   células neoplásicas  8001/1  caso_clinico_radiologia61
#  T9   linfoma B difuso de células grandes  9680/3  caso_clinico_radiologia61
#
#      endpos  startpos
#  T1   384.0     377.0
#  T2   450.0     436.0
#  T3   499.0     485.0
#  T4   557.0     521.0
#  T5   563.0     559.0
#  T6   582.0     566.0
#  T7   604.0     584.0
#  T8   755.0     736.0
#  T9   874.0     839.0  ,
#  'caso_clinico_radiologia611':          CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  miomatosis  8895/0  caso_clinico_radiologia611   185.0     175.0,
#  'caso_clinico_radiologia612':       CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  linfoma  9590/3  caso_clinico_radiologia612    41.0      34.0,
#  'caso_clinico_radiologia615':           CLAVE ICD-O-3                   documento  endpos  startpos
#  T1      linfoma  9590/3  caso_clinico_radiologia615    52.0      45.0
#  T2  metastásica  8000/6  caso_clinico_radiologia615   547.0     536.0,
#  'caso_clinico_radiologia616':             CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  masa pulmonar  8000/6  caso_clinico_radiologia616   495.0     482.0
#  T2      neoplasia  8000/1  caso_clinico_radiologia616   553.0     544.0
#  T3    metastásico  8000/6  caso_clinico_radiologia616   626.0     615.0,
#  'caso_clinico_radiologia621':      CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  cáncer  8000/3  caso_clinico_radiologia621    64.0      58.0,
#  'caso_clinico_radiologia626':         CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  formación  8000/1  caso_clinico_radiologia626   454.0     445.0,
#  'caso_clinico_radiologia63':                     CLAVE ICD-O-3                  documento  endpos  startpos
#  T1        hepatocarcinoma  8170/3  caso_clinico_radiologia63   143.0     128.0
#  T2  carcinoma metastásico  8010/6  caso_clinico_radiologia63   155.0     134.0,
#  'caso_clinico_radiologia645':          CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  neoplásico  8000/1  caso_clinico_radiologia645   493.0     483.0
#  T2   formación  8000/1  caso_clinico_radiologia645   522.0     513.0,
#  'caso_clinico_radiologia646':         CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  Carcinoma  8010/3  caso_clinico_radiologia646    46.0      37.0,
#  'caso_clinico_radiologia654':               CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  realce meníngeo  8000/6  caso_clinico_radiologia654  1149.0    1134.0,
#  'caso_clinico_radiologia657':    CLAVE ICD-O-3                   documento  endpos  startpos
#  T1    SE  9260/3  caso_clinico_radiologia657    50.0      48.0,
#  'caso_clinico_radiologia664':         CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  neoplasia  8000/1  caso_clinico_radiologia664   164.0     155.0,
#  'caso_clinico_radiologia671':          CLAVE ICD-O-3                   documento  endpos  startpos
#  T1  tumoración  8000/1  caso_clinico_radiologia671   419.0     409.0,
#  'caso_clinico_radiologia672':         CLAVE ICD-O-3                   documento  endpos  startpos
#  T1     cáncer  8000/3  caso_clinico_radiologia672   355.0     349.0
#  T2  neoplasia  8000/1  caso_clinico_radiologia672   606.0     597.0,
#  'caso_clinico_radiologia675':                              CLAVE ICD-O-3                   documento  \
#  T1              nódulos pulmonares  8000/6  caso_clinico_radiologia675
#  T2                       neoplasia  8000/1  caso_clinico_radiologia675
#  T3                      metástasis  8000/6  caso_clinico_radiologia675
#  T4                         tumoral  8000/1  caso_clinico_radiologia675
#  T5  nódulos pulmonares bilaterales  8000/6  caso_clinico_radiologia675
#
#      endpos  startpos
#  T1   469.0     451.0
#  T2   526.0     517.0
#  T3   562.0     552.0
#  T4   724.0     717.0
#  T5   904.0     874.0  ,
#  'caso_clinico_radiologia682':                      CLAVE ICD-O-3                   documento  endpos  \
#  T1  masa de partes blandas  8000/6  caso_clinico_radiologia682   299.0
# ...
#
#      startpos
#  T1    2841.0
#  T2    3140.0
#  T3    3649.0
#  T4    3680.0
#  T5    4067.0
#  T6    4171.0  ,
#  'S0004-06142008000500013-1':                CLAVE ICD-O-3                  documento  endpos  startpos
#  T1      neoformativo  8000/1  S0004-06142008000500013-1   562.0     550.0
#  T2             tumor  8000/1  S0004-06142008000500013-1   633.0     628.0
#  T3  carcinoma ductal  8500/3  S0004-06142008000500013-1   724.0     708.0
#  T4        metástasis  8000/6  S0004-06142008000500013-1  1000.0     990.0,
#  'S0004-06142008000500015-1':         CLAVE ICD-O-3                  documento  endpos  startpos
#  T1      tumor  8000/1  S0004-06142008000500015-1   281.0     276.0
#  T2  formación  8000/1  S0004-06142008000500015-1   914.0     905.0,
#  'S0004-06142008000600011-1':              CLAVE ICD-O-3                  documento  endpos  startpos
#  T1         tumoral  8000/1  S0004-06142008000600011-1   522.0     515.0
#  T2    neoformación  8000/1  S0004-06142008000600011-1  1473.0    1461.0
#  T3         T3bN0M0  8000/6  S0004-06142008000600011-1  1495.0    1488.0
#  T4    diseminación  8000/6  S0004-06142008000600011-1  2197.0    2185.0
#  T5  adenocarcinoma  8140/3  S0004-06142008000600011-1  2665.0    2651.0
#  T6   lesión lítica  8000/6  S0004-06142008000600011-1  2988.0    2975.0,
#  'S0004-06142008000600012-1':    CLAVE ICD-O-3                  documento  endpos  startpos
#  T1   LMA  9861/3  S0004-06142008000600012-1   473.0     470.0,
#  'S0004-06142008000600013-1':               CLAVE ICD-O-3                  documento  endpos  startpos
#  T1  Nódulo tiroideo  8000/6  S0004-06142008000600013-1    88.0      73.0
#  T2        Carcinoma  8010/3  S0004-06142008000600013-1   847.0     838.0,
#  'S0004-06142008000600013-2':                                               CLAVE ICD-O-3  \
#  T1                                        tumorales  8000/1
#  T2                                        neoplasia  8000/1
#  T3                                       metástasis  8000/6
#  T4                                     tumoraciones  8000/1
#  T5  metástasis de carcinoma renal de células claras  8310/6
#  T6                                     hipernefroma  8312/3
#
#                      documento  endpos  startpos
#  T1  S0004-06142008000600013-2   255.0     246.0
#  T2  S0004-06142008000600013-2   379.0     370.0
#  T3  S0004-06142008000600013-2   917.0     907.0
#  T4  S0004-06142008000600013-2  1506.0    1494.0
#  T5  S0004-06142008000600013-2  1854.0    1807.0
#  T6  S0004-06142008000600013-2  2019.0    2007.0  ,
#  'S0004-06142008000600014-1':                     CLAVE   ICD-O-3                  documento  endpos  \
#  T1              neoplasia    8000/1  S0004-06142008000600014-1   827.0
#  T2              tumorales    8000/1  S0004-06142008000600014-1   875.0
#  T3       células malignas    8001/3  S0004-06142008000600014-1  1394.0
#  T4             tumoración    8000/1  S0004-06142008000600014-1  1573.0
#  T5   tumor germinal mixto  9064/3/H  S0004-06142008000600014-1  1656.0
#  T6  carcinoma embrionario    9070/3  S0004-06142008000600014-1  1716.0
#  T7               teratoma    9080/1  S0004-06142008000600014-1  1734.0
#  T8               seminoma    9061/3  S0004-06142008000600014-1  1896.0
#
#      startpos
#  T1     818.0
#  T2     866.0
#  T3    1378.0
#  T4    1563.0
#  T5    1636.0
#  T6    1695.0
#  T7    1726.0
#  T8    1888.0  ,
#  'S0004-06142008000700009-1':                        CLAVE ICD-O-3                  documento  endpos  \
#  T1                     tumor  8000/1  S0004-06142008000700009-1   257.0
#  T2                metástasis  8000/6  S0004-06142008000700009-1   323.0
#  T3      lesiones a distancia  8000/6  S0004-06142008000700009-1   362.0
#  T4                 Carcinoma  8010/3  S0004-06142008000700009-1   751.0
#  T5              lesión renal  8000/6  S0004-06142008000700009-1  1007.0
#  T6  carcinoma neuroendocrino  8246/3  S0004-06142008000700009-1  1148.0
#
#      startpos
#  T1     252.0
#  T2     313.0
#  T3     342.0
#  T4     742.0
#  T5     995.0
#  T6    1124.0  ,
#  'S0004-06142008000700011-1':               CLAVE ICD-O-3                  documento  endpos  startpos
#  T1        tumorales  8000/1  S0004-06142008000700011-1   413.0     404.0
#  T2  Tumor fusiforme  8004/3  S0004-06142008000700011-1   724.0     709.0
#  T3       malignidad  8000/3  S0004-06142008000700011-1   769.0     759.0,
#  'S0004-06142008000700012-1':                  CLAVE   ICD-O-3                  documento  endpos  startpos
#  T1               tumor    8000/1  S0004-06142008000700012-1   467.0     462.0
#  T2      adenocarcinoma    8140/3  S0004-06142008000700012-1   609.0     595.0
#  T3  carcinoma invasivo  8010/3/H  S0004-06142008000700012-1   618.0     600.0
#  T4          metástasis    8000/6  S0004-06142008000700012-1   775.0     765.0
#  T5           neoplasia    8000/1  S0004-06142008000700012-1  1195.0    1186.0,
#  'S0004-06142008000700014-1':                 CLAVE ICD-O-3                  documento  endpos  startpos
#  T1            maligno  8000/3  S0004-06142008000700014-1   836.0     829.0
#  T2          tumorales  8000/1  S0004-06142008000700014-1  1131.0    1122.0
#  T3       sarcomatoide  8033/3  S0004-06142008000700014-1  1547.0    1535.0
#  T4         tumoración  8000/1  S0004-06142008000700014-1  1982.0    1972.0
#  T5  células tumorales  8001/1  S0004-06142008000700014-1  2496.0    2479.0,
#  'S0004-06142009000100008-1':                       CLAVE ICD-O-3                  documento  endpos  \
#  T1                    tumor  8000/1  S0004-06142009000100008-1    82.0
#  T2  adenocarcinoma mucinoso  8480/3  S0004-06142009000100008-1   481.0
#  T3                  pT2N0M0  8000/6  S0004-06142009000100008-1   528.0
#
#      startpos
#  T1      77.0
#  T2     458.0
#  T3     521.0  ,
#  'S0004-06142009000100009-1':         CLAVE ICD-O-3                  documento  endpos  startpos
#  T1